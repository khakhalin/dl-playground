# %% [markdown]
# # Optimize the set of samples for limited learning

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
class Const:
    """All constants collected together."""
    img_size = 28
    nclasses = 10
    
C = Const()

# %%
(xtrain,ytrain), (xtest,ytest) = tf.keras.datasets.mnist.load_data()

def scale_mnist(x):
    x  = x.astype('float32')/255
    x = np.expand_dims(x,3) # Weird extra axis for channels, to make keras work
    return x
    
xtrain = scale_mnist(xtrain)
xtest  = scale_mnist(xtest)

ytrain = tf.keras.utils.to_categorical(ytrain, C.nclasses)
ytest  = tf.keras.utils.to_categorical(ytest, C.nclasses)

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(C.img_size, C.img_size, 1)), # Universal input layer
        tf.keras.layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Conv2D(filters=64, kernel_size=(5,5), activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
        tf.keras.layers.Dropout(0.4),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(C.nclasses, activation='softmax')
    ])
    
    optimizer = tf.keras.optimizers.Adam()

    model.compile(loss='categorical_crossentropy',
                 optimizer=optimizer,
                 metrics=['accuracy'])
    
    return model

model = build_model()
#model.summary()

# %%
# Pick a few complete sets of digits

nrows = 5
hist = [0]*10
indices = np.zeros((nrows, 10), dtype=int)
plt.figure(figsize=(12,5))
i = 0
while min(hist) < nrows:
    label = np.argmax(ytrain[i])
    if hist[label]<nrows:
        plt.subplot(nrows, 10, 1+label+hist[label]*10)
        plt.imshow(xtrain[i,:,:,0]);
        #plt.title(label)
        plt.axis('off')
        indices[hist[label], label] = i
        hist[label] += 1
    i += 1
    
print(indices)
# Out:
# [[ 1  3  5  7  2  0 13 15 17  4]
#  [21  6 16 10  9 11 18 29 31 19]
#  [34  8 25 12 20 35 32 38 41 22]
#  [37 14 28 27 26 47 36 42 46 33]
#  [51 23 76 30 53 65 39 52 55 43]]

# %%
class PrintDot(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 10 == 0: print('')
        print(f" {logs['loss']:.3f}".replace('0.','.'), end='')

# %%
# Create a new model, and train it on 10 samples only 
def test_subset(indices):
    model2 = build_model()

    hist = model2.fit(xtrain[indices], ytrain[indices],
                      batch_size=1024,
                      epochs=40,
                      verbose=0,
                      validation_data=(xtest, ytest))

    score = model2.evaluate(xtest, ytest, verbose=0)
    return score[1] # Accuracy
    
best_val = test_subset(indices[0,:])
print(best_val)
# Out:
# 0.5593

# %%
ind = indices[0,:] # Starting value
i = max(ind)
count = 0
ind_best = []
best_val = 0
while count < 5:
    label = np.argmax(ytrain[i])
    ind[label] = i
    new_val = test_subset(ind)
    if new_val > best_val:
        count += 1
        best_val = new_val
        ind_best = ind.copy()
        print(f"New best  : {best_val}, with indices {ind}")
        plt.figure(figsize=(12,2))
        for k in range(10):
            plt.subplot(1, 10, k+1)
            plt.imshow(xtrain[ind[k],:,:,0]);
            plt.axis('off')
    else:
        print(f"Bad result: {new_val}, with index {i} (label {label})")
        ind = ind_best.copy() # Reset to previous best
    i += 1
# Out:
# New best  : 0.5848000049591064, with indices [ 1  3  5  7  2  0 13 15 17  4]
# Bad result: 0.5351999998092651, with index 18 (label 6)
# Bad result: 0.5493000149726868, with index 19 (label 9)
# New best  : 0.593500018119812, with indices [ 1  3  5  7 20  0 13 15 17  4]
# Bad result: 0.5550000071525574, with index 21 (label 0)
# Bad result: 0.5532000064849854, with index 22 (label 9)
# Bad result: 0.5629000067710876, with index 23 (label 1)
# Bad result: 0.4471000134944916, with index 24 (label 1)
# Bad result: 0.5105999708175659, with index 25 (label 2)
# Bad result: 0.5875999927520752, with index 26 (label 4)
# Bad result: 0.5430999994277954, with index 27 (label 3)
# Bad result: 0.51419997215271, with index 28 (label 2)
# Bad result: 0.558899998664856, with index 29 (label 7)
# Bad result: 0.54339998960495, with index 30 (label 3)
# Bad result: 0.5597000122070312, with index 31 (label 8)
# Bad result: 0.5455999970436096, with index 32 (label 6)
# Bad result: 0.48069998621940613, with index 33 (label 9)
# Bad result: 0.527999997138977, with index 34 (label 0)
# Bad result: 0.5699999928474426, with index 35 (label 5)
# Bad result: 0.4945000112056732, with index 36 (label 6)
# Bad result: 0.5357000231742859, with index 37 (label 0)
# Bad result: 0.4700999855995178, with index 38 (label 7)
# Bad result: 0.5516999959945679, with index 39 (label 6)
# Bad result: 0.5478000044822693, with index 40 (label 1)
# New best  : 0.605400025844574, with indices [ 1  3  5  7 20  0 13 15 41  4]
# Bad result: 0.5583000183105469, with index 42 (label 7)
# Bad result: 0.5281000137329102, with index 43 (label 9)
# Bad result: 0.5224000215530396, with index 44 (label 3)
# Bad result: 0.5407000184059143, with index 45 (label 9)
# Bad result: 0.585099995136261, with index 46 (label 8)
# Bad result: 0.5347999930381775, with index 47 (label 5)
# Bad result: 0.5023000240325928, with index 48 (label 9)
# Bad result: 0.5964000225067139, with index 49 (label 3)
# New best  : 0.6252999901771545, with indices [ 1  3  5 50 20  0 13 15 41  4]
# Bad result: 0.5412999987602234, with index 51 (label 0)
# Bad result: 0.589900016784668, with index 52 (label 7)
# Bad result: 0.559499979019165, with index 53 (label 4)
# Bad result: 0.5313000082969666, with index 54 (label 9)
# Bad result: 0.5752000212669373, with index 55 (label 8)
# Bad result: 0.5795000195503235, with index 56 (label 0)
# Bad result: 0.5931000113487244, with index 57 (label 9)
# Bad result: 0.5644000172615051, with index 58 (label 4)
# Bad result: 0.5950999855995178, with index 59 (label 1)
# Bad result: 0.5903000235557556, with index 60 (label 4)
# Bad result: 0.5954999923706055, with index 61 (label 4)
# Bad result: 0.5374000072479248, with index 62 (label 6)
# Bad result: 0.612500011920929, with index 63 (label 0)
# Bad result: 0.582099974155426, with index 64 (label 4)
# Bad result: 0.5807999968528748, with index 65 (label 5)
# Bad result: 0.5974000096321106, with index 66 (label 6)
# Bad result: 0.621999979019165, with index 67 (label 1)
# Bad result: 0.5559999942779541, with index 68 (label 0)
# Bad result: 0.5684000253677368, with index 69 (label 0)
# Bad result: 0.6055999994277954, with index 70 (label 1)
# Bad result: 0.5516999959945679, with index 71 (label 7)
# Bad result: 0.6122000217437744, with index 72 (label 1)
# Bad result: 0.5656999945640564, with index 73 (label 6)
# Bad result: 0.5726000070571899, with index 74 (label 3)
# Bad result: 0.5913000106811523, with index 75 (label 0)
# Bad result: 0.5277000069618225, with index 76 (label 2)
# New best  : 0.6366999745368958, with indices [ 1 77  5 50 20  0 13 15 41  4]

# %% [markdown]
# New best  : 0.6366999745368958, with indices [ 1 77  5 50 20  0 13 15 41  4]
